# %%
import numpy as np

# %%
import pandas as pd

# %%
#The estimated number of cases prevalent in 2018 in Poland includes males and a period of 5 years.

# %%
#Estimated number of prevalent cases in 2018, Poland, males, all ages
#*** Proportions per 100 000

# %%
prevalentCasesMalesAllAges = pd.read_csv('prevalent cases males all ages.csv')

# %%
prevalentCasesMalesAllAges
# Out:
#                                     ICD  Cancer   5-year  Proportions***
# C00-97                       Allcancers  230826  1254.50             NaN
# C61                            Prostate   52509   285.40             NaN
# C18-21                       Colorectum   38379   208.60             NaN
# C67                             Bladder   26094   141.80             NaN
# C33-34                             Lung   17892    97.20             NaN
# C64-65                           Kidney    9727    52.90             NaN
# C32                              Larynx    8628    46.90             NaN
# C00-06                   Lip,oralcavity    7304    39.70             NaN
# C91-95                        Leukaemia    6465    35.10             NaN
# C70-72       Brain,centralnervoussystem    6270    34.10             NaN
# C16                             Stomach    6090    33.10             NaN
# C62                              Testis    6003    32.60             NaN
# ...

# %%
#Estimated number of prevalent cases in 2018, Poland, males, ages 0-19
#*** Proportions per 100 000

# %%
prevalentCasesMalesAges0_19 = pd.read_csv('prevalent cases males ages 0-19.csv')

# %%
prevalentCasesMalesAges0_19
# Out:
#                                     ICD  Cancer  5-year  Proportions***
# C00-97                       Allcancers    2274   59.20             NaN
# C91-95                        Leukaemia     743   19.30             NaN
# C70-72       Brain,centralnervoussystem     371    9.70             NaN
# C62                              Testis     206    5.40             NaN
# C82-86, C96         Non-Hodgkinlymphoma     161    4.20             NaN
# C81                     Hodgkinlymphoma     115    3.00             NaN
# C64-65                           Kidney      78    2.00             NaN
# C22                               Liver      37    0.96             NaN
# C67                             Bladder      19    0.49             NaN
# C73                             Thyroid      19    0.49             NaN
# C43                      Melanomaofskin      14    0.36             NaN
# C00-06                   Lip,oralcavity       5    0.13             NaN
# ...

# %%
#Estimated number of prevalent cases in 2018, Poland, males, ages 20-34
#*** Proportions per 100 000

# %%
prevalentCasesMalesAges20_34 = pd.read_csv('prevalent cases males ages 20-34.csv')

# %%
prevalentCasesMalesAges20_34
# Out:
#                                     ICD  Cancer  5-year  Proportions***
# C00-97                       Allcancers    5565  138.90             NaN
# C62                              Testis    2332   58.20             NaN
# C70-72       Brain,centralnervoussystem     610   15.20             NaN
# C81                     Hodgkinlymphoma     395    9.90             NaN
# C82-86, C96         Non-Hodgkinlymphoma     387    9.70             NaN
# C43                      Melanomaofskin     364    9.10             NaN
# C73                             Thyroid     236    5.90             NaN
# C91-95                        Leukaemia     188    4.70             NaN
# C18-21                       Colorectum     139    3.50             NaN
# C67                             Bladder     109    2.70             NaN
# C64-65                           Kidney      75    1.90             NaN
# C00-06                   Lip,oralcavity      69    1.70             NaN
# ...

# %%
#Estimated number of prevalent cases in 2018, Poland, males, ages 35-49
#*** Proportions per 100 000

# %%
prevalentCasesMalesAges35_49 = pd.read_csv('prevalent cases males ages 35-49.csv')

# %%
prevalentCasesMalesAges35_49
# Out:
#                                     ICD  Cancer  5-year  Proportions***
# C00-97                       Allcancers   14222  331.70             NaN
# C62                              Testis    2515   58.70             NaN
# C70-72       Brain,centralnervoussystem    1256   29.30             NaN
# C18-21                       Colorectum    1061   24.70             NaN
# C43                      Melanomaofskin     986   23.00             NaN
# C00-06                   Lip,oralcavity     890   20.80             NaN
# C64-65                           Kidney     836   19.50             NaN
# C82-86, C96         Non-Hodgkinlymphoma     832   19.40             NaN
# C32                              Larynx     653   15.20             NaN
# C09-10                       Oropharynx     616   14.40             NaN
# C67                             Bladder     586   13.70             NaN
# C73                             Thyroid     521   12.20             NaN
# ...

# %%
#Estimated number of prevalent cases in 2018, Poland, males, ages 50-64
#*** Proportions per 100 000

# %%
prevalentCasesMalesAges50_64 = pd.read_csv('prevalent cases males ages 50-64.csv')

# %%
prevalentCasesMalesAges50_64
# Out:
#                                     ICD  Cancer   5-year  Proportions***
# C00-97                       Allcancers   72829  1990.80             NaN
# C18-21                       Colorectum   12285   335.80             NaN
# C61                            Prostate   11766   321.60             NaN
# C67                             Bladder    8331   227.70             NaN
# C33-34                             Lung    6865   187.70             NaN
# C32                              Larynx    4194   114.60             NaN
# C64-65                           Kidney    3858   105.50             NaN
# C00-06                   Lip,oralcavity    3090    84.50             NaN
# C09-10                       Oropharynx    2366    64.70             NaN
# C16                             Stomach    2138    58.40             NaN
# C70-72       Brain,centralnervoussystem    2123    58.00             NaN
# C91-95                        Leukaemia    1944    53.10             NaN
# ...

# %%
#Estimated number of prevalent cases in 2018, Poland, males, ages 65-84
#*** Proportions per 100 000

# %%
prevalentCasesMalesAges65_84 = pd.read_csv('prevalent cases males ages 65-84.csv')

# %%
prevalentCasesMalesAges65_84
# Out:
#                                     ICD  Cancer  5-year  Proportions***
# C00-97                       Allcancers  123553  5182.8             NaN
# C61                            Prostate   37902  1589.9             NaN
# C18-21                       Colorectum   22273   934.3             NaN
# C67                             Bladder   15081   632.6             NaN
# C33-34                             Lung    9933   416.7             NaN
# C64-65                           Kidney    4527   189.9             NaN
# C32                              Larynx    3554   149.1             NaN
# C16                             Stomach    3201   134.3             NaN
# C00-06                   Lip,oralcavity    3005   126.1             NaN
# C91-95                        Leukaemia    2831   118.8             NaN
# C43                      Melanomaofskin    2312    97.0             NaN
# C82-86, C96         Non-Hodgkinlymphoma    2243    94.1             NaN
# ...

# %%
with pd.ExcelWriter('Estimated number of prevalent cases in 2018, Poland, males.xlsx') as writer:  # doctest: +SKIP
    prevalentCasesMalesAllAges.to_excel(writer, sheet_name='All ages 0-85+')
    prevalentCasesMalesAges0_19.to_excel(writer, sheet_name='Ages 0-19')
    prevalentCasesMalesAges20_34.to_excel(writer, sheet_name='Ages 20-34')
    prevalentCasesMalesAges35_49.to_excel(writer, sheet_name='Ages 35-49')
    prevalentCasesMalesAges50_64.to_excel(writer, sheet_name='Ages 50-64')
    prevalentCasesMalesAges65_84.to_excel(writer, sheet_name='Ages 65-84')
