# %%
import numpy as np

# %%
import pandas as pd

# %%
#The estimated number of cases prevalent in 2018 in Poland includes both sexes and a period of 5 years.

# %%
#Estimated number of prevalent cases in 2018, Poland, both sexes, all ages
#*** Proportions per 100 000

# %%
prevalentCasesBothSexesAllAges = pd.read_csv('prevalent cases both sexes all ages.csv')

# %%
prevalentCasesBothSexesAllAges
# Out:
#                                     ICD  Cancer   5-year  Proportions***
# C00-97                       Allcancers  490121  1286.20             NaN
# C50                              Breast   78371   397.70             NaN
# C18-21                       Colorectum   68430   179.60             NaN
# C61                            Prostate   52509   285.40             NaN
# C67                             Bladder   34087    89.50             NaN
# C33-34                             Lung   30436    79.90             NaN
# C54                         Corpusuteri   29124   147.80             NaN
# C64-65                           Kidney   16671    43.80             NaN
# C56                               Ovary   14495    73.60             NaN
# C73                             Thyroid   14008    36.80             NaN
# C43                      Melanomaofskin   12248    32.10             NaN
# C70-72       Brain,centralnervoussystem   11948    31.40             NaN
# ...

# %%
#Estimated number of prevalent cases in 2018, Poland, both sexes, ages 0-19
#*** Proportions per 100 000

# %%
prevalentCasesBothSexesAges0_19 = pd.read_csv('prevalent cases both sexes ages 0-19.csv')

# %%
prevalentCasesBothSexesAges0_19
# Out:
#                                     ICD  Cancer  5-year  Proportions***
# C00-97                       Allcancers    4261   56.90             NaN
# C91-95                        Leukaemia    1336   17.80             NaN
# C70-72       Brain,centralnervoussystem     669    8.90             NaN
# C64-65                           Kidney     263    3.50             NaN
# C82-86, C96         Non-Hodgkinlymphoma     239    3.20             NaN
# C62                              Testis     206    5.40             NaN
# C81                     Hodgkinlymphoma     205    2.70             NaN
# C73                             Thyroid     120    1.60             NaN
# C56                               Ovary      64    1.80             NaN
# C22                               Liver      58    0.77             NaN
# C43                      Melanomaofskin      28    0.37             NaN
# C67                             Bladder      24    0.32             NaN
# ...

# %%
#Estimated number of prevalent cases in 2018, Poland, both sexes, ages 20-34
#*** Proportions per 100 000

# %%
prevalentCasesBothSexesAges20_34 = pd.read_csv('prevalent cases both sexes ages 20-34.csv')

# %%
prevalentCasesBothSexesAges20_34
# Out:
#                                     ICD  Cancer  5-year  Proportions***
# C00-97                       Allcancers   11896  151.70             NaN
# C62                              Testis    2332   58.20             NaN
# C73                             Thyroid    1638   20.90             NaN
# C50                              Breast    1381   36.00             NaN
# C70-72       Brain,centralnervoussystem     945   12.10             NaN
# C56                               Ovary     807   21.10             NaN
# C81                     Hodgkinlymphoma     733    9.30             NaN
# C43                      Melanomaofskin     681    8.70             NaN
# C82-86, C96         Non-Hodgkinlymphoma     644    8.20             NaN
# C53                         Cervixuteri     439   11.50             NaN
# C91-95                        Leukaemia     326    4.20             NaN
# C18-21                       Colorectum     243    3.10             NaN
# ...

# %%
#Estimated number of prevalent cases in 2018, Poland, both sexes, ages 35-49
#*** Proportions per 100 000

# %%
prevalentCasesBothSexesAges35_49 = pd.read_csv('prevalent cases both sexes ages 35-49.csv')

# %%
prevalentCasesBothSexesAges35_49
# Out:
#                                     ICD  Cancer  5-year  Proportions***
# C00-97                       Allcancers   41923  490.80             NaN
# C50                              Breast   11972  281.40             NaN
# C73                             Thyroid    3676   43.00             NaN
# C56                               Ovary    2771   65.10             NaN
# C62                              Testis    2515   58.70             NaN
# C18-21                       Colorectum    2268   26.60             NaN
# C70-72       Brain,centralnervoussystem    2033   23.80             NaN
# C53                         Cervixuteri    1967   46.20             NaN
# C43                      Melanomaofskin    1696   19.90             NaN
# C54                         Corpusuteri    1366   32.10             NaN
# C82-86, C96         Non-Hodgkinlymphoma    1345   15.70             NaN
# C64-65                           Kidney    1299   15.20             NaN
# ...

# %%
#Estimated number of prevalent cases in 2018, Poland, both sexes, ages 50-64
#*** Proportions per 100 000

# %%
prevalentCasesBothSexesAges50_64 = pd.read_csv('prevalent cases both sexes ages 50-64.csv')

# %%
prevalentCasesBothSexesAges50_64
# Out:
#                                     ICD  Cancer   5-year  Proportions***
# C00-97                       Allcancers  162232  2127.60             NaN
# C50                              Breast   32109   809.40             NaN
# C18-21                       Colorectum   20079   263.30             NaN
# C33-34                             Lung   11951   156.70             NaN
# C61                            Prostate   11766   321.60             NaN
# C67                             Bladder   10746   140.90             NaN
# C54                         Corpusuteri   10287   259.30             NaN
# C64-65                           Kidney    6100    80.00             NaN
# C56                               Ovary    5586   140.80             NaN
# C73                             Thyroid    5245    68.80             NaN
# C32                              Larynx    4885    64.10             NaN
# C00-06                   Lip,oralcavity    4039    53.00             NaN
# ...

# %%
#Estimated number of prevalent cases in 2018, Poland, both sexes, ages 65-84
#*** Proportions per 100 000

# %%
prevalentCasesBothSexesAges65_84 = pd.read_csv('prevalent cases both sexes ages 65-84.csv')

# %%
prevalentCasesBothSexesAges65_84
# Out:
#                                     ICD  Cancer   5-year  Proportions***
# C00-97                       Allcancers  239804  4117.30             NaN
# C18-21                       Colorectum   39098   671.30             NaN
# C61                            Prostate   37902  1589.90             NaN
# C50                              Breast   30605   889.60             NaN
# C67                             Bladder   19408   333.20             NaN
# C33-34                             Lung   16726   287.20             NaN
# C54                         Corpusuteri   15703   456.40             NaN
# C64-65                           Kidney    8058   138.40             NaN
# C43                      Melanomaofskin    5234    89.90             NaN
# C16                             Stomach    5213    89.50             NaN
# C91-95                        Leukaemia    5146    88.40             NaN
# C82-86, C96         Non-Hodgkinlymphoma    5017    86.10             NaN
# ...

# %%
with pd.ExcelWriter('Estimated number of prevalent cases in 2018, Poland, both sexes.xlsx') as writer:  # doctest: +SKIP
    prevalentCasesBothSexesAllAges.to_excel(writer, sheet_name='All ages 0-85+')
    prevalentCasesBothSexesAges0_19.to_excel(writer, sheet_name='Ages 0-19')
    prevalentCasesBothSexesAges20_34.to_excel(writer, sheet_name='Ages 20-34')
    prevalentCasesBothSexesAges35_49.to_excel(writer, sheet_name='Ages 35-49')
    prevalentCasesBothSexesAges50_64.to_excel(writer, sheet_name='Ages 50-64')
    prevalentCasesBothSexesAges65_84.to_excel(writer, sheet_name='Ages 65-84')
