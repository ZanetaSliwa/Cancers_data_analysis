# %%
import numpy as np

# %%
import pandas as pd

# %%
#Estimated number of deaths in 2018, Poland, males, all ages
#* Crude and age-standardized rates per 100 000

# %%
deathsMalesAllAges = pd.read_csv('deaths males all ages.csv')

# %%
deathsMalesAllAges
# Out:
#                                     ICD  Cancer             Number  \
# C00-97                       Allcancers   62606  [61999.5-63218.4]
# C33-34                             Lung   17135  [16612.4-17674.0]
# C18-21                       Colorectum    8104       Notavailable
# C61                            Prostate    5763    [5427.0-6119.8]
# C16                             Stomach    3684    [3491.9-3886.7]
# C67                             Bladder    3453    [3238.4-3681.8]
# C25                            Pancreas    2872    [2703.9-3050.5]
# C64-65                           Kidney    1956    [1823.2-2098.5]
# C70-72       Brain,centralnervoussystem    1910    [1739.6-2097.1]
# C91-95                        Leukaemia    1756    [1578.7-1953.2]
# C32                              Larynx    1546    [1390.0-1719.5]
# C15                          Oesophagus    1338    [1212.0-1477.0]
# C22                               Liver    1305    [1194.3-1426.0]
# ...

# %%
#Estimated number of deaths in 2018, Poland, males, ages 0-19
#* Crude and age-standardized rates per 100 000
#** Cumulative risk, ages 0-19 (in %)

# %%
deathsMalesAges0_19 = pd.read_csv('deaths males ages 0-19.csv')

# %%
deathsMalesAges0_19
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers     112  Notavailable
# C70-72       Brain,centralnervoussystem      40  Notavailable
# C91-95                        Leukaemia      30  Notavailable
# C82-86, C96         Non-Hodgkinlymphoma       7  Notavailable
# C64-65                           Kidney       3  Notavailable
# C62                              Testis       3  Notavailable
# C22                               Liver       2  Notavailable
#
#              Uncertainty interval  Crude Rate*  ASR (World)*  Cum. risk**
# C00-97                       2.90         2.90          0.06          NaN
# C70-72                       1.00         1.10          0.02          NaN
# C91-95                       0.78         0.77          0.02          NaN
# C82-86, C96                  0.18         0.18          0.00          NaN
# C64-65                       0.08         0.08          0.00          NaN
# ...

# %%
#Estimated number of deaths in 2018, Poland, males, ages 20-34
#* Crude and age-standardized rates per 100 000
#** Cumulative risk, ages 20-34 (in %)

# %%
deathsMalesAges20_34 = pd.read_csv('deaths males ages 20-34.csv')

# %%
deathsMalesAges20_34
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers     397  Notavailable
# C70-72       Brain,centralnervoussystem      75  Notavailable
# C62                              Testis      55  Notavailable
# C91-95                        Leukaemia      46  Notavailable
# C82-86, C96         Non-Hodgkinlymphoma      36  Notavailable
# C18-21                       Colorectum      27  Notavailable
# C43                      Melanomaofskin      24  Notavailable
# C16                             Stomach      18  Notavailable
# C25                            Pancreas      13  Notavailable
# C22                               Liver      13  Notavailable
# C81                     Hodgkinlymphoma      13  Notavailable
# C33-34                             Lung      11  Notavailable
# C64-65                           Kidney       5  Notavailable
# C15                          Oesophagus       3  Notavailable
# ...

# %%
#Estimated number of deaths in 2018, Poland, males, ages 35-49
#* Crude and age-standardized rates per 100 000
#** Cumulative risk, ages 35-49 (in %)

# %%
deathsMalesAges35_49 = pd.read_csv('deaths males ages 35-49.csv')

# %%
deathsMalesAges35_49
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers    2176  Notavailable
# C70-72       Brain,centralnervoussystem     250  Notavailable
# C33-34                             Lung     237  Notavailable
# C18-21                       Colorectum     173  Notavailable
# C16                             Stomach     171  Notavailable
# C00-06                   Lip,oralcavity     138  Notavailable
# C25                            Pancreas     132  Notavailable
# C43                      Melanomaofskin      93  Notavailable
# C15                          Oesophagus      88  Notavailable
# C82-86, C96         Non-Hodgkinlymphoma      88  Notavailable
# C91-95                        Leukaemia      80  Notavailable
# C32                              Larynx      79  Notavailable
# C64-65                           Kidney      74  Notavailable
# C22                               Liver      63  Notavailable
# ...

# %%
#Estimated number of deaths in 2018, Poland, males, ages 50-64
#* Crude and age-standardized rates per 100 000
#** Cumulative risk, ages 50-64 (in %)

# %%
deathsMalesAges50_64 = pd.read_csv('deaths males ages 50-64.csv')

# %%
deathsMalesAges50_64
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers   17780  Notavailable
# C33-34                             Lung    5619  Notavailable
# C18-21                       Colorectum    1959  Notavailable
# C16                             Stomach    1057  Notavailable
# C25                            Pancreas     982  Notavailable
# C67                             Bladder     715  Notavailable
# C61                            Prostate     679  Notavailable
# C32                              Larynx     679  Notavailable
# C70-72       Brain,centralnervoussystem     672  Notavailable
# C00-06                   Lip,oralcavity     580  Notavailable
# C15                          Oesophagus     572  Notavailable
# C64-65                           Kidney     560  Notavailable
# C91-95                        Leukaemia     410  Notavailable
# C22                               Liver     397  Notavailable
# ...

# %%
#Estimated number of deaths in 2018, Poland, males, ages 65-84
#* Crude and age-standardized rates per 100 000
#** Cumulative risk, ages 65-84 (in %)

# %%
deathsMalesAges65_84 = pd.read_csv('deaths males ages 65-84.csv')

# %%
deathsMalesAges65_84
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers   35487  Notavailable
# C33-34                             Lung   10217  Notavailable
# C18-21                       Colorectum    5002  Notavailable
# C61                            Prostate    3769  Notavailable
# C67                             Bladder    2159  Notavailable
# C16                             Stomach    2082  Notavailable
# C25                            Pancreas    1551  Notavailable
# C64-65                           Kidney    1119  Notavailable
# C91-95                        Leukaemia     986  Notavailable
# C70-72       Brain,centralnervoussystem     783  Notavailable
# C32                              Larynx     731  Notavailable
# C22                               Liver     719  Notavailable
# C15                          Oesophagus     613  Notavailable
# C82-86, C96         Non-Hodgkinlymphoma     582  Notavailable
# ...

# %%
with pd.ExcelWriter('Estimated number of deaths in 2018, Poland, males.xlsx') as writer:  # doctest: +SKIP
    deathsMalesAllAges.to_excel(writer, sheet_name='All ages 0-85+')
    deathsMalesAges0_19.to_excel(writer, sheet_name='Ages 0-19')
    deathsMalesAges20_34.to_excel(writer, sheet_name='Ages 20-34')
    deathsMalesAges35_49.to_excel(writer, sheet_name='Ages 35-49')
    deathsMalesAges50_64.to_excel(writer, sheet_name='Ages 50-64')
    deathsMalesAges65_84.to_excel(writer, sheet_name='Ages 65-84')
