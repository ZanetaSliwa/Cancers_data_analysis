# %%
import numpy as np

# %%
import pandas as pd

# %%
#The estimated number of cases prevalent in 2018 in Poland includes females and a period of 5 years.

# %%
#Estimated number of prevalent cases in 2018, Poland, females, all ages
#*** Proportions per 100 000

# %%
prevalentCasesFemalesAllAges = pd.read_csv('prevalent cases females all ages.csv')

# %%
prevalentCasesFemalesAllAges
# Out:
#                                     ICD  Cancer   5-year  Proportions***
# C00-97                       Allcancers  259295  1315.90             NaN
# C50                              Breast   78371   397.70             NaN
# C18-21                       Colorectum   30051   152.50             NaN
# C54                         Corpusuteri   29124   147.80             NaN
# C56                               Ovary   14495    73.60             NaN
# C33-34                             Lung   12544    63.70             NaN
# C73                             Thyroid   11654    59.10             NaN
# C53                         Cervixuteri    9821    49.80             NaN
# C67                             Bladder    7993    40.60             NaN
# C64-65                           Kidney    6944    35.20             NaN
# C43                      Melanomaofskin    6371    32.30             NaN
# C82-86, C96         Non-Hodgkinlymphoma    5845    29.70             NaN
# ...

# %%
#Estimated number of prevalent cases in 2018, Poland, females, ages 0-19
#*** Proportions per 100 000

# %%
prevalentCasesFemalesAges0_19 = pd.read_csv('prevalent cases females ages 0-19.csv')

# %%
prevalentCasesFemalesAges0_19
# Out:
#                                     ICD  Cancer  5-year  Proportions***
# C00-97                       Allcancers    1987   54.50             NaN
# C91-95                        Leukaemia     593   16.30             NaN
# C70-72       Brain,centralnervoussystem     298    8.20             NaN
# C64-65                           Kidney     185    5.10             NaN
# C73                             Thyroid     101    2.80             NaN
# C81                     Hodgkinlymphoma      90    2.50             NaN
# C82-86, C96         Non-Hodgkinlymphoma      78    2.10             NaN
# C56                               Ovary      64    1.80             NaN
# C22                               Liver      21    0.58             NaN
# C43                      Melanomaofskin      14    0.38             NaN
# C18-21                       Colorectum      10    0.27             NaN
# C00-06                   Lip,oralcavity       8    0.22             NaN
# ...

# %%
#Estimated number of prevalent cases in 2018, Poland, females, ages 20-34
#*** Proportions per 100 000

# %%
prevalentCasesFemalesAges20_34 = pd.read_csv('prevalent cases females ages 20-34.csv')

# %%
prevalentCasesFemalesAges20_34
# Out:
#                                     ICD  Cancer  5-year  Proportions***
# C00-97                       Allcancers    6331  165.20             NaN
# C73                             Thyroid    1402   36.60             NaN
# C50                              Breast    1381   36.00             NaN
# C56                               Ovary     807   21.10             NaN
# C53                         Cervixuteri     439   11.50             NaN
# C81                     Hodgkinlymphoma     338    8.80             NaN
# C70-72       Brain,centralnervoussystem     335    8.70             NaN
# C43                      Melanomaofskin     317    8.30             NaN
# C82-86, C96         Non-Hodgkinlymphoma     257    6.70             NaN
# C91-95                        Leukaemia     138    3.60             NaN
# C54                         Corpusuteri     114    3.00             NaN
# C18-21                       Colorectum     104    2.70             NaN
# ...

# %%
#Estimated number of prevalent cases in 2018, Poland, females, ages 35-49
#*** Proportions per 100 000

# %%
prevalentCasesFemalesAges35_49 = pd.read_csv('prevalent cases females ages 35-49.csv')

# %%
prevalentCasesFemalesAges35_49
# Out:
#                                     ICD  Cancer  5-year  Proportions***
# C00-97                       Allcancers   27701  651.10             NaN
# C50                              Breast   11972  281.40             NaN
# C73                             Thyroid    3155   74.20             NaN
# C56                               Ovary    2771   65.10             NaN
# C53                         Cervixuteri    1967   46.20             NaN
# C54                         Corpusuteri    1366   32.10             NaN
# C18-21                       Colorectum    1207   28.40             NaN
# C70-72       Brain,centralnervoussystem     777   18.30             NaN
# C43                      Melanomaofskin     710   16.70             NaN
# C82-86, C96         Non-Hodgkinlymphoma     513   12.10             NaN
# C64-65                           Kidney     463   10.90             NaN
# C67                             Bladder     290    6.80             NaN
# ...

# %%
#Estimated number of prevalent cases in 2018, Poland, females, ages 50-64
#*** Proportions per 100 000

# %%
prevalentCasesFemalesAges50_64 = pd.read_csv('prevalent cases females ages 50-64.csv')

# %%
prevalentCasesFemalesAges50_64
# Out:
#                                     ICD  Cancer   5-year  Proportions***
# C00-97                       Allcancers   89403  2253.70             NaN
# C50                              Breast   32109   809.40             NaN
# C54                         Corpusuteri   10287   259.30             NaN
# C18-21                       Colorectum    7794   196.50             NaN
# C56                               Ovary    5586   140.80             NaN
# C33-34                             Lung    5086   128.20             NaN
# C73                             Thyroid    4322   109.00             NaN
# C53                         Cervixuteri    4021   101.40             NaN
# C67                             Bladder    2415    60.90             NaN
# C64-65                           Kidney    2242    56.50             NaN
# C82-86, C96         Non-Hodgkinlymphoma    1835    46.30             NaN
# C70-72       Brain,centralnervoussystem    1755    44.20             NaN
# ...

# %%
#Estimated number of prevalent cases in 2018, Poland, females, ages 65-84
#*** Proportions per 100 000

# %%
prevalentCasesFemalesAges65_84 = pd.read_csv('prevalent cases females ages 65-84.csv')

# %%
prevalentCasesFemalesAges65_84
# Out:
#                                     ICD  Cancer   5-year  Proportions***
# C00-97                       Allcancers  116251  3379.00             NaN
# C50                              Breast   30605   889.60             NaN
# C18-21                       Colorectum   16825   489.00             NaN
# C54                         Corpusuteri   15703   456.40             NaN
# C33-34                             Lung    6793   197.50             NaN
# C56                               Ovary    4851   141.00             NaN
# C67                             Bladder    4327   125.80             NaN
# C64-65                           Kidney    3531   102.60             NaN
# C53                         Cervixuteri    3008    87.40             NaN
# C43                      Melanomaofskin    2922    84.90             NaN
# C82-86, C96         Non-Hodgkinlymphoma    2774    80.60             NaN
# C73                             Thyroid    2601    75.60             NaN
# ...

# %%
with pd.ExcelWriter('Estimated number of prevalent cases in 2018, Poland, females.xlsx') as writer:  # doctest: +SKIP
    prevalentCasesFemalesAllAges.to_excel(writer, sheet_name='All ages 0-85+')
    prevalentCasesFemalesAges0_19.to_excel(writer, sheet_name='Ages 0-19')
    prevalentCasesFemalesAges20_34.to_excel(writer, sheet_name='Ages 20-34')
    prevalentCasesFemalesAges35_49.to_excel(writer, sheet_name='Ages 35-49')
    prevalentCasesFemalesAges50_64.to_excel(writer, sheet_name='Ages 50-64')
    prevalentCasesFemalesAges65_84.to_excel(writer, sheet_name='Ages 65-84')
