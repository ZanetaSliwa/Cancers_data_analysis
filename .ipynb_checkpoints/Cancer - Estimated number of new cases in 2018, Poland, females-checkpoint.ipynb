# %%
import numpy as np

# %%
import pandas as pd

# %%
#Estimated number of new cases in 2018, Poland, females, all ages
#* Crude and age-standardized rates per 100 000

# %%
newCasesFemalesAllAges = pd.read_csv('new cases females all ages.csv')

# %%
newCasesFemalesAllAges
# Out:
#                                     ICD  Cancer             Number  \
# C00-97                       Allcancers   90294  [89230.9-91369.7]
# C50                              Breast   20203  [19082.6-21389.1]
# C33-34                             Lung   10588  [10061.3-11142.3]
# C18-21                       Colorectum   10480       Notavailable
# C54                         Corpusuteri    7847    [7440.3-8275.9]
# C56                               Ovary    5077    [4757.3-5418.1]
# C53                         Cervixuteri    3220    [2994.2-3462.8]
# C73                             Thyroid    2968    [2514.3-3503.6]
# C25                            Pancreas    2864    [2620.0-3130.7]
# C67                             Bladder    2686    [2435.4-2962.4]
# C64-65                           Kidney    2562    [2355.5-2786.6]
# C16                             Stomach    2484    [2277.5-2709.2]
# C82-86, C96         Non-Hodgkinlymphoma    1982    [1788.4-2196.6]
# ...

# %%
#Estimated number of new cases in 2018, Poland, females, ages 0-19
#* Crude and age-standardized rates per 100 000
#** Cumulative risk, ages 0-19 (in %)

# %%
newCasesFemalesAges0_19 = pd.read_csv('new cases females ages 0-19.csv')

# %%
newCasesFemalesAges0_19
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers     527  Notavailable
# C91-95                        Leukaemia     136  Notavailable
# C70-72       Brain,centralnervoussystem      93  Notavailable
# C73                             Thyroid      36  Notavailable
# C64-65                           Kidney      33  Notavailable
# C81                     Hodgkinlymphoma      33  Notavailable
# C56                               Ovary      21  Notavailable
# C82-86, C96         Non-Hodgkinlymphoma      21  Notavailable
# C22                               Liver       6  Notavailable
# C43                      Melanomaofskin       4  Notavailable
# C07-08                   Salivaryglands       3  Notavailable
# C18-21                       Colorectum       3  Notavailable
# C67                             Bladder       2  Notavailable
# C33-34                             Lung       1  Notavailable
# ...

# %%
#Estimated number of new cases in 2018, Poland, females, ages 20-34
#* Crude and age-standardized rates per 100 000
#** Cumulative risk, ages 20-34 (in %)

# %%
newCasesFemalesAges20_34 = pd.read_csv('new cases females ages 20-34.csv')

# %%
newCasesFemalesAges20_34
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers    1978  Notavailable
# C50                              Breast     572  Notavailable
# C73                             Thyroid     384  Notavailable
# C56                               Ovary     204  Notavailable
# C53                         Cervixuteri     133  Notavailable
# C70-72       Brain,centralnervoussystem      96  Notavailable
# C43                      Melanomaofskin      91  Notavailable
# C82-86, C96         Non-Hodgkinlymphoma      74  Notavailable
# C81                     Hodgkinlymphoma      72  Notavailable
# C54                         Corpusuteri      50  Notavailable
# C91-95                        Leukaemia      38  Notavailable
# C18-21                       Colorectum      36  Notavailable
# C16                             Stomach      27  Notavailable
# C33-34                             Lung      20  Notavailable
# ...

# %%
#Estimated number of new cases in 2018, Poland, females, ages 35-49
#* Crude and age-standardized rates per 100 000
#** Cumulative risk, ages 35-49 (in %)

# %%
newCasesFemalesAges35_49 = pd.read_csv('new cases females ages 35-49.csv')

# %%
newCasesFemalesAges35_49
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers    8667  Notavailable
# C50                              Breast    3661  Notavailable
# C56                               Ovary     886  Notavailable
# C73                             Thyroid     771  Notavailable
# C53                         Cervixuteri     610  Notavailable
# C54                         Corpusuteri     457  Notavailable
# C18-21                       Colorectum     441  Notavailable
# C70-72       Brain,centralnervoussystem     219  Notavailable
# C43                      Melanomaofskin     209  Notavailable
# C33-34                             Lung     179  Notavailable
# C64-65                           Kidney     164  Notavailable
# C82-86, C96         Non-Hodgkinlymphoma     158  Notavailable
# C16                             Stomach     148  Notavailable
# C67                             Bladder      93  Notavailable
# ...

# %%
#Estimated number of new cases in 2018, Poland, females, ages 50-64
#* Crude and age-standardized rates per 100 000
#** Cumulative risk, ages 50-64 (in %)

# %%
newCasesFemalesAges50_64 = pd.read_csv('new cases females ages 50-64.csv')

# %%
newCasesFemalesAges50_64
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers   28834  Notavailable
# C50                              Breast    7997  Notavailable
# C33-34                             Lung    3867  Notavailable
# C54                         Corpusuteri    2793  Notavailable
# C18-21                       Colorectum    2662  Notavailable
# C56                               Ovary    1802  Notavailable
# C53                         Cervixuteri    1198  Notavailable
# C73                             Thyroid    1010  Notavailable
# C64-65                           Kidney     803  Notavailable
# C67                             Bladder     774  Notavailable
# C25                            Pancreas     633  Notavailable
# C82-86, C96         Non-Hodgkinlymphoma     552  Notavailable
# C16                             Stomach     550  Notavailable
# C70-72       Brain,centralnervoussystem     532  Notavailable
# ...

# %%
#Estimated number of new cases in 2018, Poland, females, ages 65-84
#* Crude and age-standardized rates per 100 000
#** Cumulative risk, ages 65-84 (in %)

# %%
newCasesFemalesAges65_84 = pd.read_csv('new cases females ages 65-84.csv')

# %%
newCasesFemalesAges65_84
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers   42286  Notavailable
# C50                              Breast    7369  Notavailable
# C33-34                             Lung    5955  Notavailable
# C18-21                       Colorectum    5851  Notavailable
# C54                         Corpusuteri    4077  Notavailable
# C56                               Ovary    1886  Notavailable
# C25                            Pancreas    1672  Notavailable
# C67                             Bladder    1442  Notavailable
# C16                             Stomach    1329  Notavailable
# C64-65                           Kidney    1306  Notavailable
# C53                         Cervixuteri    1101  Notavailable
# C82-86, C96         Non-Hodgkinlymphoma     980  Notavailable
# C91-95                        Leukaemia     919  Notavailable
# C43                      Melanomaofskin     890  Notavailable
# ...

# %%
with pd.ExcelWriter('Estimated number of new cases in 2018, Poland, Females.xlsx') as writer:  # doctest: +SKIP
    newCasesFemalesAllAges.to_excel(writer, sheet_name='All ages 0-85+')
    newCasesFemalesAges0_19.to_excel(writer, sheet_name='Ages 0-19')
    newCasesFemalesAges20_34.to_excel(writer, sheet_name='Ages 20-34')
    newCasesFemalesAges35_49.to_excel(writer, sheet_name='Ages 35-49')
    newCasesFemalesAges50_64.to_excel(writer, sheet_name='Ages 50-64')
    newCasesFemalesAges65_84.to_excel(writer, sheet_name='Ages 65-84')
