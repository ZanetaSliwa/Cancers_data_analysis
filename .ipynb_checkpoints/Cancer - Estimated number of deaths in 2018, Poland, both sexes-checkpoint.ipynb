# %%
import numpy as np

# %%
import pandas as pd

# %%
#Estimated number of deaths in 2018, Poland, both sexes, all ages
#* Crude and age-standardized rates per 100 000

# %%
deathsBothSexesAllAges = pd.read_csv('deaths both sexes all ages.csv')

# %%
deathsBothSexesAllAges
# Out:
#                                     ICD  Cancer               Number  \
# C00-97                       Allcancers  113388  [112564.0-114218.0]
# C33-34                             Lung   26509    [25861.6-27172.6]
# C18-21                       Colorectum   14362         Notavailable
# C50                              Breast    6921      [6732.9-7114.3]
# C16                             Stomach    5779      [5528.6-6040.8]
# C61                            Prostate    5763      [5427.0-6119.8]
# C25                            Pancreas    5715      [5477.7-5962.5]
# C67                             Bladder    4450      [4204.3-4710.0]
# C70-72       Brain,centralnervoussystem    3383      [3187.4-3590.6]
# C56                               Ovary    3204      [3001.2-3420.5]
# C64-65                           Kidney    3092      [2929.5-3263.6]
# C91-95                        Leukaemia    3089      [2872.2-3322.2]
# C22                               Liver    2230      [2092.9-2376.1]
# ...

# %%
#Estimated number of deaths in 2018, Poland, both sexes, ages 0-19
#* Crude and age-standardized rates per 100 000
#** Cumulative risk, ages 0-19 (in %)

# %%
deathsBothSexesAges0_19 = pd.read_csv('deaths both sexes ages 0-19.csv')

# %%
deathsBothSexesAges0_19
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers     195  Notavailable
# C70-72       Brain,centralnervoussystem      66  Notavailable
# C91-95                        Leukaemia      51  Notavailable
# C82-86, C96         Non-Hodgkinlymphoma      13  Notavailable
# C64-65                           Kidney       5  Notavailable
# C22                               Liver       4  Notavailable
# C62                              Testis       3  Notavailable
# C43                      Melanomaofskin       1  Notavailable
# C81                     Hodgkinlymphoma       1  Notavailable
#
#              Uncertainty interval  Crude Rate*  ASR (World)*  Cum. risk**
# C00-97                       2.60         2.60          0.05          NaN
# C70-72                       0.88         0.90          0.02          NaN
# C91-95                       0.68         0.68          0.01          NaN
# ...

# %%
#Estimated number of deaths in 2018, Poland, both sexes, ages 20-34
#* Crude and age-standardized rates per 100 000
#** Cumulative risk, ages 20-34 (in %)

# %%
deathsBothSexesAges20_34 = pd.read_csv('deaths both sexes ages 20-34.csv')

# %%
deathsBothSexesAges20_34
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers     667  Notavailable
# C70-72       Brain,centralnervoussystem     113  Notavailable
# C91-95                        Leukaemia      68  Notavailable
# C82-86, C96         Non-Hodgkinlymphoma      65  Notavailable
# C62                              Testis      55  Notavailable
# C50                              Breast      46  Notavailable
# C18-21                       Colorectum      43  Notavailable
# C16                             Stomach      30  Notavailable
# C43                      Melanomaofskin      29  Notavailable
# C56                               Ovary      22  Notavailable
# C81                     Hodgkinlymphoma      21  Notavailable
# C22                               Liver      18  Notavailable
# C33-34                             Lung      17  Notavailable
# C25                            Pancreas      16  Notavailable
# ...

# %%
#Estimated number of deaths in 2018, Poland, both sexes, ages 35-49
#* Crude and age-standardized rates per 100 000
#** Cumulative risk, ages 35-49 (in %)

# %%
deathsBothSexesAges35_49 = pd.read_csv('deaths both sexes ages 35-49.csv')

# %%
deathsBothSexesAges35_49
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers    4308  Notavailable
# C50                              Breast     598  Notavailable
# C33-34                             Lung     384  Notavailable
# C70-72       Brain,centralnervoussystem     381  Notavailable
# C18-21                       Colorectum     338  Notavailable
# C56                               Ovary     279  Notavailable
# C16                             Stomach     273  Notavailable
# C53                         Cervixuteri     211  Notavailable
# C25                            Pancreas     200  Notavailable
# C00-06                   Lip,oralcavity     157  Notavailable
# C43                      Melanomaofskin     156  Notavailable
# C82-86, C96         Non-Hodgkinlymphoma     130  Notavailable
# C91-95                        Leukaemia     129  Notavailable
# C64-65                           Kidney     104  Notavailable
# ...

# %%
#Estimated number of deaths in 2018, Poland, both sexes, ages 50-64
#* Crude and age-standardized rates per 100 000
#** Cumulative risk, ages 50-64 (in %)

# %%
deathsBothSexesAges50_64 = pd.read_csv('deaths both sexes ages 50-64.csv')

# %%
deathsBothSexesAges50_64
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers   30344  Notavailable
# C33-34                             Lung    8832  Notavailable
# C18-21                       Colorectum    3076  Notavailable
# C50                              Breast    2014  Notavailable
# C25                            Pancreas    1603  Notavailable
# C16                             Stomach    1460  Notavailable
# C70-72       Brain,centralnervoussystem    1089  Notavailable
# C56                               Ovary    1073  Notavailable
# C67                             Bladder     891  Notavailable
# C64-65                           Kidney     790  Notavailable
# C32                              Larynx     773  Notavailable
# C00-06                   Lip,oralcavity     714  Notavailable
# C61                            Prostate     679  Notavailable
# C53                         Cervixuteri     679  Notavailable
# ...

# %%
#Estimated number of deaths in 2018, Poland, both sexes, ages 65-84
#* Crude and age-standardized rates per 100 000
#** Cumulative risk, ages 65-84 (in %)

# %%
deathsBothSexesAges65_84 = pd.read_csv('deaths both sexes ages 65-84.csv')

# %%
deathsBothSexesAges65_84
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers   62781  Notavailable
# C33-34                             Lung   15677  Notavailable
# C18-21                       Colorectum    8582  Notavailable
# C61                            Prostate    3769  Notavailable
# C50                              Breast    3267  Notavailable
# C16                             Stomach    3244  Notavailable
# C25                            Pancreas    3225  Notavailable
# C67                             Bladder    2714  Notavailable
# C64-65                           Kidney    1802  Notavailable
# C91-95                        Leukaemia    1741  Notavailable
# C56                               Ovary    1555  Notavailable
# C70-72       Brain,centralnervoussystem    1488  Notavailable
# C22                               Liver    1252  Notavailable
# C54                         Corpusuteri    1247  Notavailable
# ...

# %%
with pd.ExcelWriter('Estimated number of deaths in 2018, Poland, both sexes.xlsx') as writer:  # doctest: +SKIP
    deathsBothSexesAllAges.to_excel(writer, sheet_name='All ages 0-85+')
    deathsBothSexesAges0_19.to_excel(writer, sheet_name='Ages 0-19')
    deathsBothSexesAges20_34.to_excel(writer, sheet_name='Ages 20-34')
    deathsBothSexesAges35_49.to_excel(writer, sheet_name='Ages 35-49')
    deathsBothSexesAges50_64.to_excel(writer, sheet_name='Ages 50-64')
    deathsBothSexesAges65_84.to_excel(writer, sheet_name='Ages 65-84')
