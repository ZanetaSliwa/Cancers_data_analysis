# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# #Estimated number of new cases in 2018, Poland, both sexes, all ages.
# #* Crude and age-standardized rates per 100 000

# %%
newCasesBothSexesAllAges = pd.read_csv('new cases both sexes all ages.csv')

# %%
newCasesBothSexesAllAges
# Out:
#                                     ICD  Cancer               Number  \
# C00-97                       Allcancers  185630  [184050.0-187223.0]
# C33-34                             Lung   28583    [27823.7-29363.1]
# C18-21                       Colorectum   24507         Notavailable
# C50                              Breast   20203    [19082.6-21389.1]
# C61                            Prostate   15393    [14679.7-16140.9]
# C67                             Bladder   10883    [10400.4-11388.0]
# C54                         Corpusuteri    7847      [7440.3-8275.9]
# C16                             Stomach    6659      [6322.8-7013.0]
# C64-65                           Kidney    6327      [6001.2-6670.5]
# C25                            Pancreas    5786      [5432.4-6162.6]
# C56                               Ovary    5077      [4757.3-5418.1]
# C70-72       Brain,centralnervoussystem    4283      [4006.4-4578.7]
# C91-95                        Leukaemia    4184      [3918.2-4467.9]
# ...

# %% [markdown]
# Estimated number of new cases in 2018, Poland, both sexes, ages 0-19.
# #* Crude and age-standardized rates per 100 000
# #** Cumulative risk, ages 0-19 (in %)

# %%
newCasesBothSexesAges0_19 = pd.read_csv('new cases both sexes ages 0-19.csv')

# %%
newCasesBothSexesAges0_19
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers    1172  Notavailable
# C91-95                        Leukaemia     317  Notavailable
# C70-72       Brain,centralnervoussystem     204  Notavailable
# C62                              Testis      88  Notavailable
# C81                     Hodgkinlymphoma      73  Notavailable
# C82-86, C96         Non-Hodgkinlymphoma      64  Notavailable
# C64-65                           Kidney      52  Notavailable
# C73                             Thyroid      44  Notavailable
# C56                               Ovary      21  Notavailable
# C22                               Liver      17  Notavailable
# C43                      Melanomaofskin       8  Notavailable
# C67                             Bladder       4  Notavailable
# C07-08                   Salivaryglands       3  Notavailable
# C18-21                       Colorectum       3  Notavailable
# ...

# %% [markdown]
# Estimated number of new cases in 2018, Poland, both sexes, ages 20-34
# #* Crude and age-standardized rates per 100 000
# #** Cumulative risk, ages 20-34 (in %)

# %%
newCasesBothSexesAges20_34 = pd.read_csv('new cases both sexes ages 20-34.csv')

# %%
newCasesBothSexesAges20_34
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers    3581  Notavailable
# C62                              Testis     620  Notavailable
# C50                              Breast     572  Notavailable
# C73                             Thyroid     449  Notavailable
# C70-72       Brain,centralnervoussystem     270  Notavailable
# C56                               Ovary     204  Notavailable
# C43                      Melanomaofskin     197  Notavailable
# C82-86, C96         Non-Hodgkinlymphoma     183  Notavailable
# C81                     Hodgkinlymphoma     160  Notavailable
# C53                         Cervixuteri     133  Notavailable
# C18-21                       Colorectum      99  Notavailable
# C91-95                        Leukaemia      95  Notavailable
# C67                             Bladder      55  Notavailable
# C54                         Corpusuteri      50  Notavailable
# ...

# %% [markdown]
# Estimated number of new cases in 2018, Poland, both sexes, ages 35-49
# #* Crude and age-standardized rates per 100 000
# #** Cumulative risk, ages 35-49 (in %)

# %%
newCasesBothSexesAges35_49 = pd.read_csv('new cases both sexes ages 35-49.csv')

# %%
newCasesBothSexesAges35_49
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers   13717  Notavailable
# C50                              Breast    3661  Notavailable
# C73                             Thyroid     907  Notavailable
# C56                               Ovary     886  Notavailable
# C18-21                       Colorectum     856  Notavailable
# C53                         Cervixuteri     610  Notavailable
# C70-72       Brain,centralnervoussystem     603  Notavailable
# C33-34                             Lung     554  Notavailable
# C62                              Testis     509  Notavailable
# C64-65                           Kidney     495  Notavailable
# C43                      Melanomaofskin     491  Notavailable
# C54                         Corpusuteri     457  Notavailable
# C82-86, C96         Non-Hodgkinlymphoma     410  Notavailable
# C16                             Stomach     391  Notavailable
# ...

# %% [markdown]
# Estimated number of new cases in 2018, Poland, both sexes, ages 50-64
# #* Crude and age-standardized rates per 100 000
# #** Cumulative risk, ages 50-64 (in %)

# %%
newCasesBothSexesAges50_64 = pd.read_csv("new cases both sexes ages 50-64.csv")

# %%
newCasesBothSexesAges50_64
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers   60298  Notavailable
# C33-34                             Lung   10183  Notavailable
# C50                              Breast    7997  Notavailable
# C18-21                       Colorectum    7222  Notavailable
# C61                            Prostate    4162  Notavailable
# C67                             Bladder    3386  Notavailable
# C54                         Corpusuteri    2793  Notavailable
# C64-65                           Kidney    2273  Notavailable
# C16                             Stomach    1895  Notavailable
# C56                               Ovary    1802  Notavailable
# C25                            Pancreas    1651  Notavailable
# C32                              Larynx    1601  Notavailable
# C00-06                   Lip,oralcavity    1357  Notavailable
# C70-72       Brain,centralnervoussystem    1337  Notavailable
# ...

# %% [markdown]
# Estimated number of new cases in 2018, Poland, both sexes, ages 65-84
# #* Crude and age-standardized rates per 100 000
# #** Cumulative risk, ages 65-84 (in %)

# %%
newCasesBothSexesAges65_84 = pd.read_csv("new cases both sexes ages 65-84.csv")

# %%
newCasesBothSexesAges65_84
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers   93159  Notavailable
# C33-34                             Lung   16194  Notavailable
# C18-21                       Colorectum   13894  Notavailable
# C61                            Prostate   10471  Notavailable
# C50                              Breast    7369  Notavailable
# C67                             Bladder    6167  Notavailable
# C54                         Corpusuteri    4077  Notavailable
# C16                             Stomach    3562  Notavailable
# C25                            Pancreas    3212  Notavailable
# C64-65                           Kidney    3039  Notavailable
# C91-95                        Leukaemia    2042  Notavailable
# C56                               Ovary    1886  Notavailable
# C82-86, C96         Non-Hodgkinlymphoma    1828  Notavailable
# C43                      Melanomaofskin    1610  Notavailable
# ...

# %%
with pd.ExcelWriter('Estimated number of new cases in 2018, Poland, both sexes.xlsx') as writer:  # doctest: +SKIP
    newCasesBothSexesAllAges.to_excel(writer, sheet_name='All ages 0-85+')
    newCasesBothSexesAges0_19.to_excel(writer, sheet_name='Ages 0-19')
    newCasesBothSexesAges20_34.to_excel(writer, sheet_name='Ages 20-34')
    newCasesBothSexesAges35_49.to_excel(writer, sheet_name='Ages 35-49')
    newCasesBothSexesAges50_64.to_excel(writer, sheet_name='Ages 50-64')
    newCasesBothSexesAges65_84.to_excel(writer, sheet_name='Ages 65-84')
