# %%
import numpy as np

# %%
import pandas as pd

# %%
#Estimated number of new cases in 2018, Poland, males, all ages
#* Crude and age-standardized rates per 100 000

# %%
newCasesMalesAllAges = pd.read_csv('new cases males all ages.csv')

# %%
newCasesMalesAllAges
# Out:
#                                     ICD  Cancer             Number  \
# C00-97                       Allcancers   95336  [94166.2-96520.3]
# C33-34                             Lung   17995  [17433.6-18574.5]
# C61                            Prostate   15393  [14679.7-16140.9]
# C18-21                       Colorectum   14027       Notavailable
# C67                             Bladder    8197    [7788.0-8627.4]
# C16                             Stomach    4175    [3914.0-4453.5]
# C64-65                           Kidney    3765    [3517.5-4029.9]
# C25                            Pancreas    2922    [2672.4-3195.0]
# C32                              Larynx    2758    [2536.3-2999.1]
# C70-72       Brain,centralnervoussystem    2381    [2166.8-2616.4]
# C00-06                   Lip,oralcavity    2380    [2141.8-2644.7]
# C91-95                        Leukaemia    2332    [2135.6-2546.4]
# C82-86, C96         Non-Hodgkinlymphoma    1997    [1805.8-2208.4]
# ...

# %%
#Estimated number of new cases in 2018, Poland, males, ages 0-19
#* Crude and age-standardized rates per 100 000
#** Cumulative risk, ages 0-19 (in %)

# %%
newCasesMalesAges0_19 = pd.read_csv('new cases males ages 0-19.csv')

# %%
newCasesMalesAges0_19
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers     645  Notavailable
# C91-95                        Leukaemia     181  Notavailable
# C70-72       Brain,centralnervoussystem     111  Notavailable
# C62                              Testis      88  Notavailable
# C82-86, C96         Non-Hodgkinlymphoma      43  Notavailable
# C81                     Hodgkinlymphoma      40  Notavailable
# C64-65                           Kidney      19  Notavailable
# C22                               Liver      11  Notavailable
# C73                             Thyroid       8  Notavailable
# C43                      Melanomaofskin       4  Notavailable
# C67                             Bladder       2  Notavailable
# C00-06                   Lip,oralcavity       1  Notavailable
# C60                               Penis       1  Notavailable
#
#              Uncertainty interval  Crude Rate*  ASR (World)*  Cum. risk**
# ...

# %%
#Estimated number of new cases in 2018, Poland, males, ages 20-34
#* Crude and age-standardized rates per 100 000
#** Cumulative risk, ages 20-34 (in %)

# %%
newCasesMalesAges20_34 = pd.read_csv('new cases males ages 20-34.csv')

# %%
newCasesMalesAges20_34
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers    1603  Notavailable
# C62                              Testis     620  Notavailable
# C70-72       Brain,centralnervoussystem     174  Notavailable
# C82-86, C96         Non-Hodgkinlymphoma     109  Notavailable
# C43                      Melanomaofskin     106  Notavailable
# C81                     Hodgkinlymphoma      88  Notavailable
# C73                             Thyroid      65  Notavailable
# C18-21                       Colorectum      63  Notavailable
# C91-95                        Leukaemia      57  Notavailable
# C67                             Bladder      35  Notavailable
# C64-65                           Kidney      28  Notavailable
# C00-06                   Lip,oralcavity      28  Notavailable
# C22                               Liver      17  Notavailable
# C11                         Nasopharynx      17  Notavailable
# ...

# %%
#Estimated number of new cases in 2018, Poland, males, ages 35-49
#* Crude and age-standardized rates per 100 000
#** Cumulative risk, ages 35-49 (in %)

# %%
newCasesMalesAges35_49 = pd.read_csv('new cases males ages 35-49.csv')

# %%
newCasesMalesAges35_49
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers    5050  Notavailable
# C62                              Testis     509  Notavailable
# C18-21                       Colorectum     415  Notavailable
# C70-72       Brain,centralnervoussystem     384  Notavailable
# C33-34                             Lung     375  Notavailable
# C64-65                           Kidney     331  Notavailable
# C00-06                   Lip,oralcavity     318  Notavailable
# C43                      Melanomaofskin     282  Notavailable
# C32                              Larynx     260  Notavailable
# C82-86, C96         Non-Hodgkinlymphoma     252  Notavailable
# C16                             Stomach     243  Notavailable
# C67                             Bladder     187  Notavailable
# C09-10                       Oropharynx     182  Notavailable
# C25                            Pancreas     157  Notavailable
# ...

# %%
#Estimated number of new cases in 2018, Poland, males, ages 50-64
#* Crude and age-standardized rates per 100 000
#** Cumulative risk, ages 50-64 (in %)

# %%
newCasesMalesAges50_64 = pd.read_csv('new cases males ages 50-64.csv')

# %%
newCasesMalesAges50_64
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers   31464  Notavailable
# C33-34                             Lung    6316  Notavailable
# C18-21                       Colorectum    4560  Notavailable
# C61                            Prostate    4162  Notavailable
# C67                             Bladder    2612  Notavailable
# C64-65                           Kidney    1470  Notavailable
# C32                              Larynx    1379  Notavailable
# C16                             Stomach    1345  Notavailable
# C00-06                   Lip,oralcavity    1052  Notavailable
# C25                            Pancreas    1018  Notavailable
# C70-72       Brain,centralnervoussystem     805  Notavailable
# C09-10                       Oropharynx     684  Notavailable
# C91-95                        Leukaemia     639  Notavailable
# C82-86, C96         Non-Hodgkinlymphoma     611  Notavailable
# ...

# %%
#Estimated number of new cases in 2018, Poland, males, ages 65-84
#* Crude and age-standardized rates per 100 000
#** Cumulative risk, ages 65-84 (in %)

# %%
newCasesMalesAges65_84 = pd.read_csv('new cases males ages 65-84.csv')

# %%
newCasesMalesAges65_84
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers   50873  Notavailable
# C61                            Prostate   10471  Notavailable
# C33-34                             Lung   10239  Notavailable
# C18-21                       Colorectum    8043  Notavailable
# C67                             Bladder    4725  Notavailable
# C16                             Stomach    2233  Notavailable
# C64-65                           Kidney    1733  Notavailable
# C25                            Pancreas    1540  Notavailable
# C91-95                        Leukaemia    1123  Notavailable
# C32                              Larynx    1052  Notavailable
# C00-06                   Lip,oralcavity     908  Notavailable
# C82-86, C96         Non-Hodgkinlymphoma     848  Notavailable
# C70-72       Brain,centralnervoussystem     812  Notavailable
# C22                               Liver     797  Notavailable
# ...

# %%
with pd.ExcelWriter('Estimated number of new cases in 2018, Poland, Males.xlsx') as writer:  # doctest: +SKIP
    newCasesMalesAllAges.to_excel(writer, sheet_name='All ages 0-85+')
    newCasesMalesAges0_19.to_excel(writer, sheet_name='Ages 0-19')
    newCasesMalesAges20_34.to_excel(writer, sheet_name='Ages 20-34')
    newCasesMalesAges35_49.to_excel(writer, sheet_name='Ages 35-49')
    newCasesMalesAges50_64.to_excel(writer, sheet_name='Ages 50-64')
    newCasesMalesAges65_84.to_excel(writer, sheet_name='Ages 65-84')
