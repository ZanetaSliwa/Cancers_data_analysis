# %%
import numpy as np

# %%
import pandas as pd

# %%
#Estimated number of deaths in 2018, Poland, females, all ages
#* Crude and age-standardized rates per 100 000

# %%
deathsFemalesAllAges = pd.read_csv('deaths females all ages.csv')

# %%
deathsFemalesAllAges
# Out:
#                                     ICD  Cancer             Number  \
# C00-97                       Allcancers   50782  [50227.0-51343.1]
# C33-34                             Lung    9374    [8997.0-9766.8]
# C50                              Breast    6921    [6732.9-7114.3]
# C18-21                       Colorectum    6258       Notavailable
# C56                               Ovary    3204    [3001.2-3420.5]
# C25                            Pancreas    2843    [2678.4-3017.7]
# C16                             Stomach    2095    [1936.1-2266.9]
# C54                         Corpusuteri    2007    [1851.1-2176.0]
# C53                         Cervixuteri    1947    [1801.1-2104.7]
# C70-72       Brain,centralnervoussystem    1473    [1363.5-1591.3]
# C91-95                        Leukaemia    1333    [1206.5-1472.8]
# C23-24                      Gallbladder    1282    [1178.9-1394.2]
# C64-65                           Kidney    1136    [1044.1-1236.0]
# ...

# %%
#Estimated number of deaths in 2018, Poland, females, ages 0-19
#* Crude and age-standardized rates per 100 000
#** Cumulative risk, ages 0-19 (in %)

# %%
deathsFemalesAges0_19 = pd.read_csv('deaths females ages 0-19.csv')

# %%
deathsFemalesAges0_19
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers      83  Notavailable
# C70-72       Brain,centralnervoussystem      26  Notavailable
# C91-95                        Leukaemia      21  Notavailable
# C82-86, C96         Non-Hodgkinlymphoma       6  Notavailable
# C64-65                           Kidney       2  Notavailable
# C22                               Liver       2  Notavailable
# C43                      Melanomaofskin       1  Notavailable
# C81                     Hodgkinlymphoma       1  Notavailable
#
#              Uncertainty interval  Crude Rate*  ASR (World)*  Cum. risk**
# C00-97                       2.30         2.30          0.05          NaN
# C70-72                       0.71         0.74          0.01          NaN
# C91-95                       0.58         0.59          0.01          NaN
# C82-86, C96                  0.16         0.16          0.00          NaN
# ...

# %%
#Estimated number of deaths in 2018, Poland, females, ages 20-34
#* Crude and age-standardized rates per 100 000
#** Cumulative risk, ages 20-34 (in %)

# %%
deathsFemalesAges20_34 = pd.read_csv('deaths females ages 20-34.csv')

# %%
deathsFemalesAges20_34
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers     270  Notavailable
# C50                              Breast      46  Notavailable
# C70-72       Brain,centralnervoussystem      38  Notavailable
# C82-86, C96         Non-Hodgkinlymphoma      29  Notavailable
# C56                               Ovary      22  Notavailable
# C91-95                        Leukaemia      22  Notavailable
# C53                         Cervixuteri      16  Notavailable
# C18-21                       Colorectum      16  Notavailable
# C16                             Stomach      12  Notavailable
# C81                     Hodgkinlymphoma       8  Notavailable
# C33-34                             Lung       6  Notavailable
# C22                               Liver       5  Notavailable
# C43                      Melanomaofskin       5  Notavailable
# C25                            Pancreas       3  Notavailable
# ...

# %%
#Estimated number of deaths in 2018, Poland, females, ages 35-49
#* Crude and age-standardized rates per 100 000
#** Cumulative risk, ages 35-49 (in %)

# %%
deathsFemalesAges35_49 = pd.read_csv('deaths females ages 35-49.csv')

# %%
deathsFemalesAges35_49
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers    2132  Notavailable
# C50                              Breast     598  Notavailable
# C56                               Ovary     279  Notavailable
# C53                         Cervixuteri     211  Notavailable
# C18-21                       Colorectum     165  Notavailable
# C33-34                             Lung     147  Notavailable
# C70-72       Brain,centralnervoussystem     131  Notavailable
# C16                             Stomach     102  Notavailable
# C25                            Pancreas      68  Notavailable
# C43                      Melanomaofskin      63  Notavailable
# C91-95                        Leukaemia      49  Notavailable
# C82-86, C96         Non-Hodgkinlymphoma      42  Notavailable
# C64-65                           Kidney      30  Notavailable
# C23-24                      Gallbladder      27  Notavailable
# ...

# %%
#Estimated number of deaths in 2018, Poland, females, ages 50-64
#* Crude and age-standardized rates per 100 000
#** Cumulative risk, ages 50-64 (in %)

# %%
deathsFemalesAges50_64 = pd.read_csv('deaths females ages 50-64.csv')

# %%
deathsFemalesAges50_64
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers   12564  Notavailable
# C33-34                             Lung    3213  Notavailable
# C50                              Breast    2014  Notavailable
# C18-21                       Colorectum    1117  Notavailable
# C56                               Ovary    1073  Notavailable
# C53                         Cervixuteri     679  Notavailable
# C25                            Pancreas     621  Notavailable
# C70-72       Brain,centralnervoussystem     417  Notavailable
# C16                             Stomach     403  Notavailable
# C54                         Corpusuteri     366  Notavailable
# C23-24                      Gallbladder     257  Notavailable
# C64-65                           Kidney     230  Notavailable
# C91-95                        Leukaemia     228  Notavailable
# C82-86, C96         Non-Hodgkinlymphoma     207  Notavailable
# ...

# %%
#Estimated number of deaths in 2018, Poland, females, ages 65-84
#* Crude and age-standardized rates per 100 000
#** Cumulative risk, ages 65-84 (in %)

# %%
deathsFemalesAges65_84 = pd.read_csv('deaths females ages 65-84.csv')

# %%
deathsFemalesAges65_84
# Out:
#                                     ICD  Cancer        Number  \
# C00-97                       Allcancers   27294  Notavailable
# C33-34                             Lung    5460  Notavailable
# C18-21                       Colorectum    3580  Notavailable
# C50                              Breast    3267  Notavailable
# C25                            Pancreas    1674  Notavailable
# C56                               Ovary    1555  Notavailable
# C54                         Corpusuteri    1247  Notavailable
# C16                             Stomach    1162  Notavailable
# C53                         Cervixuteri     850  Notavailable
# C91-95                        Leukaemia     755  Notavailable
# C23-24                      Gallbladder     754  Notavailable
# C70-72       Brain,centralnervoussystem     705  Notavailable
# C64-65                           Kidney     683  Notavailable
# C82-86, C96         Non-Hodgkinlymphoma     621  Notavailable
# ...

# %%
with pd.ExcelWriter('Estimated number of deaths in 2018, Poland, females.xlsx') as writer:  # doctest: +SKIP
    deathsFemalesAllAges.to_excel(writer, sheet_name='All ages 0-85+')
    deathsFemalesAges0_19.to_excel(writer, sheet_name='Ages 0-19')
    deathsFemalesAges20_34.to_excel(writer, sheet_name='Ages 20-34')
    deathsFemalesAges35_49.to_excel(writer, sheet_name='Ages 35-49')
    deathsFemalesAges50_64.to_excel(writer, sheet_name='Ages 50-64')
    deathsFemalesAges65_84.to_excel(writer, sheet_name='Ages 65-84')
